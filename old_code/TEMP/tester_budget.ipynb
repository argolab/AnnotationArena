# %%
import sys
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from budget_tester import *

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
# Usage
VOI_MODEL_PATH = "/export/fs06/psingh54/ActiveRubric-Internal/outputs/models/enhanced_gradient_voi_q0_both.pth"
TEST_DATASET_PATH = "/export/fs06/psingh54/ActiveRubric-Internal/outputs/data/test.json"

tester = OverallRMSETester(VOI_MODEL_PATH, TEST_DATASET_PATH)
results, query_logs = tester.run_overall_rmse_analysis(num_examples=50, budget=5)
# Out:
# Loaded VOI model and 240 test examples
# Starting overall RMSE analysis: 50 examples, budget 5
# Testing examples:   0%|          | 0/50 [00:00<?, ?it/s]
